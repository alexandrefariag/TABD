# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
import pyspark.sql.functions as f
from pyspark.sql.types import *

spark = SparkSession.builder.master('local[2]').getOrCreate()

# %%
socialnetworkusersinselectedcountries = spark.read.csv("hdfs://hdfs-nn:9000/user/Projeto TABD/Bronze/SocialNetworkUsersInSelectedCountriesIn2020And2025.csv", 
                                                 header=True, 
                                                 sep=";")

# %%
socialnetworkusersinselectedcountries.printSchema()
socialnetworkusersinselectedcountries.show()
socialnetworkusersinselectedcountries.toPandas()
# Out:
# root
#  |-- Countries: string (nullable = true)
#  |-- 2020: string (nullable = true)
#  |-- 2025*: string (nullable = true)
#
# +----------------+------+--------+
# |       Countries|  2020|   2025*|
# +----------------+------+--------+
# |China (mainland)|926,84|1 135,13|
# |           India|349,97|   490,3|
# |       Indonesia|198,96|  256,11|
# |   United States|223,03|  243,42|
# |          Brazil|141,45|  157,85|
# |      Bangladesh| 58,77|    99,3|
# |          Mexico| 80,88|   95,22|
# |         Vietnam| 73,56|   93,68|
# |     Philippines| 79,58|   90,04|
# |           Japan| 86,06|   89,08|
# |          Russia| 72,81|   75,48|
# |          Turkey| 54,34|   71,44|
# |        Thailand| 52,72|   61,77|
# |  United Kingdom| 48,63|   50,89|
# |     South Korea| 44,47|   45,53|
# |         Germany| 44,48|   45,41|
# |         Nigeria| 28,15|   44,63|
# |          France| 36,92|   38,51|
# |           Italy| 34,02|   36,09|
# |          Canada| 25,35|   32,07|
# +----------------+------+--------+
#            Countries    2020     2025*
# 0   China (mainland)  926,84  1 135,13
# 1              India  349,97     490,3
# 2          Indonesia  198,96    256,11
# 3      United States  223,03    243,42
# 4             Brazil  141,45    157,85
# 5         Bangladesh   58,77      99,3
# 6             Mexico   80,88     95,22
# 7            Vietnam   73,56     93,68
# 8        Philippines   79,58     90,04
# 9              Japan   86,06     89,08
# 10            Russia   72,81     75,48
# 11            Turkey   54,34     71,44
# 12          Thailand   52,72     61,77
# 13    United Kingdom   48,63     50,89
# 14       South Korea   44,47     45,53
# 15           Germany   44,48     45,41
# 16           Nigeria   28,15     44,63
# 17            France   36,92     38,51
# 18             Italy   34,02     36,09
# 19            Canada   25,35     32,07

# %%
socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.selectExpr("Countries as country", 
                                                                             "`2020` as users2020",
                                                                             "`2025*` as users2025")

# %%
socialnetworkusersinselectedcountries.toPandas()
# Out:
#              country users2020 users2025
# 0   China (mainland)    926,84  1 135,13
# 1              India    349,97     490,3
# 2          Indonesia    198,96    256,11
# 3      United States    223,03    243,42
# 4             Brazil    141,45    157,85
# 5         Bangladesh     58,77      99,3
# 6             Mexico     80,88     95,22
# 7            Vietnam     73,56     93,68
# 8        Philippines     79,58     90,04
# 9              Japan     86,06     89,08
# 10            Russia     72,81     75,48
# 11            Turkey     54,34     71,44
# 12          Thailand     52,72     61,77
# 13    United Kingdom     48,63     50,89
# 14       South Korea     44,47     45,53
# 15           Germany     44,48     45,41
# 16           Nigeria     28,15     44,63
# 17            France     36,92     38,51
# 18             Italy     34,02     36,09
# 19            Canada     25,35     32,07

# %%
# Unpivot - Columns to rows
socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.select(
        col("country"),
        expr("stack(2, 'users2020', `users2020`, 'users2025', `users2025`) as (year,social_media_users)")
)

# %%
socialnetworkusersinselectedcountries.toPandas()
# Out:
#              country       year social_media_users
# 0   China (mainland)  users2020             926,84
# 1   China (mainland)  users2025           1 135,13
# 2              India  users2020             349,97
# 3              India  users2025              490,3
# 4          Indonesia  users2020             198,96
# 5          Indonesia  users2025             256,11
# 6      United States  users2020             223,03
# 7      United States  users2025             243,42
# 8             Brazil  users2020             141,45
# 9             Brazil  users2025             157,85
# 10        Bangladesh  users2020              58,77
# 11        Bangladesh  users2025               99,3
# 12            Mexico  users2020              80,88
# 13            Mexico  users2025              95,22
# 14           Vietnam  users2020              73,56
# 15           Vietnam  users2025              93,68
# 16       Philippines  users2020              79,58
# 17       Philippines  users2025              90,04
# 18             Japan  users2020              86,06
# 19             Japan  users2025              89,08
# 20            Russia  users2020              72,81
# 21            Russia  users2025              75,48
# 22            Turkey  users2020              54,34
# 23            Turkey  users2025              71,44
# 24          Thailand  users2020              52,72
# 25          Thailand  users2025              61,77
# 26    United Kingdom  users2020              48,63
# 27    United Kingdom  users2025              50,89
# 28       South Korea  users2020              44,47
# 29       South Korea  users2025              45,53
# 30           Germany  users2020              44,48
# 31           Germany  users2025              45,41
# 32           Nigeria  users2020              28,15
# 33           Nigeria  users2025              44,63
# 34            France  users2020              36,92
# 35            France  users2025              38,51
# 36             Italy  users2020              34,02
# 37             Italy  users2025              36,09
# 38            Canada  users2020              25,35
# 39            Canada  users2025              32,07

# %%
socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "year",
    f.regexp_replace(col("year"),"users2020", "2020"))

socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "year",
    f.regexp_replace(col("year"),"users2025", "2025"))

socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "year",
    socialnetworkusersinselectedcountries["year"].cast(IntegerType()))

socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "social_media_users",
    f.regexp_replace(col("social_media_users")," ", ""))


socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "social_media_users",
    f.regexp_replace(col("social_media_users"),",", "."))

socialnetworkusersinselectedcountries = socialnetworkusersinselectedcountries.withColumn(
    "social_media_users",
    socialnetworkusersinselectedcountries["social_media_users"].cast(FloatType()))

# %%
socialnetworkusersinselectedcountries.toPandas()
# Out:
#              country  year  social_media_users
# 0   China (mainland)  2020          926.840027
# 1   China (mainland)  2025         1135.130005
# 2              India  2020          349.970001
# 3              India  2025          490.299988
# 4          Indonesia  2020          198.960007
# 5          Indonesia  2025          256.109985
# 6      United States  2020          223.029999
# 7      United States  2025          243.419998
# 8             Brazil  2020          141.449997
# 9             Brazil  2025          157.850006
# 10        Bangladesh  2020           58.770000
# 11        Bangladesh  2025           99.300003
# 12            Mexico  2020           80.879997
# 13            Mexico  2025           95.220001
# 14           Vietnam  2020           73.559998
# 15           Vietnam  2025           93.680000
# 16       Philippines  2020           79.580002
# 17       Philippines  2025           90.040001
# 18             Japan  2020           86.059998
# 19             Japan  2025           89.080002
# 20            Russia  2020           72.809998
# 21            Russia  2025           75.480003
# 22            Turkey  2020           54.340000
# 23            Turkey  2025           71.440002
# 24          Thailand  2020           52.720001
# 25          Thailand  2025           61.770000
# 26    United Kingdom  2020           48.630001
# 27    United Kingdom  2025           50.889999
# 28       South Korea  2020           44.470001
# 29       South Korea  2025           45.529999
# 30           Germany  2020           44.480000
# 31           Germany  2025           45.410000
# 32           Nigeria  2020           28.150000
# 33           Nigeria  2025           44.630001
# 34            France  2020           36.919998
# 35            France  2025           38.509998
# 36             Italy  2020           34.020000
# 37             Italy  2025           36.090000
# 38            Canada  2020           25.350000
# 39            Canada  2025           32.070000

# %%
socialnetworkusersinselectedcountries.printSchema()
# Out:
# root
#  |-- country: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- social_media_users: float (nullable = true)

# %%
socialnetworkusersinselectedcountries \
    .write \
    .format("parquet") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/warehouse/tabd.db/SocialNetworkUsersInSelectedCountriesIn2020And2025/")

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# spark = SparkSession.builder.master('local[2]').getOrCreate()

from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|adultinternetusag...|      false|
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalinternetusa...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|internetusagefreq...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# +--------+--------------------+-----------+
# only showing top 20 rows

# %%
spark.sql(
    """
    
    REFRESH TABLE tabd_db.IndividualsActivities1
    
    """
)

spark.sql(
    """
    SELECT *
    FROM tabd_db.IndividualsActivities1
    
    """
).toPandas()
# Out:
#       year                    region internet_activity  activity_percentage  \
# 0     2011  European Union from 2020              null                   20
# 1     2012  European Union from 2020              null                   25
# 2     2013  European Union from 2020              null                   24
# 3     2014  European Union from 2020              null                   28
# 4     2015  European Union from 2020              null                   28
# ...    ...                       ...               ...                  ...
# 5755  2016               South Korea              null                    0
# 5756  2017               South Korea              null                    0
# 5757  2018               South Korea              null                    0
# 5758  2019               South Korea              null                    0
# 5759  2020               South Korea              null                    0
#
#                                  individuals
# 0                            All Individuals
# 1                            All Individuals
# 2                            All Individuals
# 3                            All Individuals
# 4                            All Individuals
# ...                                      ...
# 5755  Individuals with high formal education
# 5756  Individuals with high formal education
# 5757  Individuals with high formal education
# 5758  Individuals with high formal education
# 5759  Individuals with high formal education
#
# [5760 rows x 5 columns]

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.IndividualsActivities2
    
    """
).toPandas()
# Out:
#       year                    region  \
# 0     2011  European Union from 2020
# 1     2012  European Union from 2020
# 2     2013  European Union from 2020
# 3     2014  European Union from 2020
# 4     2015  European Union from 2020
# ...    ...                       ...
# 5275  2016               South Korea
# 5276  2017               South Korea
# 5277  2018               South Korea
# 5278  2019               South Korea
# 5279  2020               South Korea
#
#                                       internet_activity  activity_percentage  \
# 0     Looking for information about education, train...                   28
# 1     Looking for information about education, train...                    0
# 2     Looking for information about education, train...                   30
# 3     Looking for information about education, train...                    0
# 4     Looking for information about education, train...                   31
# ...                                                 ...                  ...
# 5275  Playing/downloading games, listening to music ...                    0
# 5276  Playing/downloading games, listening to music ...                    0
# 5277  Playing/downloading games, listening to music ...                    0
# 5278  Playing/downloading games, listening to music ...                    0
# 5279  Playing/downloading games, listening to music ...                    0
#
#      individuals
# 0           null
# 1           null
# 2           null
# 3           null
# 4           null
# ...          ...
# 5275        null
# 5276        null
# 5277        null
# 5278        null
# 5279        null
#
# [5280 rows x 5 columns]

# %%
internetusage = spark.sql(
    """
    
    SELECT DISTINCT tabd_db.IndividualsActivities1.year, tabd_db.IndividualsActivities1.region,
           tabd_db.IndividualsActivities2.internet_activity,
           tabd_db.IndividualsActivities2.activity_percentage,
           tabd_db.IndividualsActivities1.individuals
           
    
    FROM tabd_db.IndividualsActivities1 INNER JOIN tabd_db.IndividualsActivities2 
         ON tabd_db.IndividualsActivities1.year = tabd_db.IndividualsActivities2.year and 
         tabd_db.IndividualsActivities1.region = tabd_db.IndividualsActivities2.region
  
    """
)

# %%
spark.sql(
    """
    
    SELECT DISTINCT tabd_db.IndividualsActivities1.year, tabd_db.IndividualsActivities1.region,
           tabd_db.IndividualsActivities2.internet_activity,
           tabd_db.IndividualsActivities2.activity_percentage,
           tabd_db.IndividualsActivities1.individuals
           
    
    FROM tabd_db.IndividualsActivities1 INNER JOIN tabd_db.IndividualsActivities2 
         ON tabd_db.IndividualsActivities1.year = tabd_db.IndividualsActivities2.year and 
         tabd_db.IndividualsActivities1.region = tabd_db.IndividualsActivities2.region
  
    """
).toPandas()
# Out:
#        year                    region  \
# 0      2018  European Union from 2020
# 1      2014  European Union from 2020
# 2      2015  European Union from 2020
# 3      2013  European Union from 2020
# 4      2018  European Union from 2020
# ...     ...                       ...
# 63355  2015               South Korea
# 63356  2017               South Korea
# 63357  2018               South Korea
# 63358  2011               South Korea
# 63359  2018               South Korea
#
#                                        internet_activity  activity_percentage  \
# 0      Looking for information about education, train...                    0
# 1                              Sending/receiving e-mails                   67
# 2                              Sending/receiving e-mails                   67
# 3      Playing/downloading games, images, films or music                    0
# 4         Listening to web radios and/or watching web TV                    0
# ...                                                  ...                  ...
# 63355       Finding information about goods and services                    0
# 63356  Playing/downloading games, images, films or music                    0
# 63357  Playing/downloading games, images, films or music                    0
# 63358     Listening to web radios and/or watching web TV                    0
# 63359                         Seeking health information                    0
#
#                                        individuals
# 0         Individuals with medium formal education
# 1            Individuals with 15 years old or less
# 2              Individuals with 55 to 64 years old
# 3           Individuals with high formal education
# 4                                  All Individuals
# ...                                            ...
# 63355        Individuals with 15 years old or less
# 63356          Individuals with 16 to 24 years old
# 63357          Individuals with 25 to 34 years old
# 63358  Individuals with no or low formal education
# 63359  Individuals with no or low formal education
#
# [63360 rows x 5 columns]

# %%
internetusage \
    .write \
    .format("parquet") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/warehouse/tabd.db/P_IndividualsActivities/")

# %%
spark.sql(
    """
    DROP TABLE tabd_db.IndividualsActivities1
    
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    DROP TABLE tabd_db.IndividualsActivities2
    
    """
)
# Out:
# DataFrame[]

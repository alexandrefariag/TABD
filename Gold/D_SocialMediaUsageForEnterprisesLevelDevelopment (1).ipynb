# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# spark = SparkSession.builder.master('local[2]').getOrCreate()

from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|           countries|      false|
# | tabd_db|countryinternetusers|      false|
# | tabd_db|dailyinternetusag...|      false|
# | tabd_db|    internetjoindate|      false|
# | tabd_db|listleastdevelope...|      false|
# | tabd_db|listofcountriesby...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausebyp...|      false|
# | tabd_db|socialmediausebyt...|      false|
# +--------+--------------------+-----------+

# %%
spark.sql(
    """
    
    REFRESH TABLE tabd_db.P_CountryInternetUsers
    
    """
)
spark.sql(
    """
    SELECT *
    FROM tabd_db.P_CountryInternetUsers
    
    """
).toPandas()
# Out:
#     country_or_area area_km  current_account_balance  internet_hosts  \
# 0            France  547030             -305000000.0       2396761.0
# 1           Nigeria  923768                      0.0          1142.0
# 2          Malaysia  329750                      0.0        107971.0
# 3             Yemen  527970              369900000.0           138.0
# 4      Burkina Faso  274200             -471700000.0           442.0
# ..              ...     ...                      ...             ...
# 210        Maldives    None                      NaN             NaN
# 211          Monaco    None                      NaN             NaN
# 212          Brunei    None                      NaN             NaN
# 213           Tonga    None                      NaN             NaN
# 214       Gibraltar    None                      NaN             NaN
#
#      telephone_main_lines_in_use  telephone_mobile_celular country_id  status  \
# 0                     33905400.0                41683100.0       None     NaN
# 1                       853100.0                 3149500.0       None     NaN
# 2                      4571600.0                11124100.0       None     NaN
# 3                       542200.0                  411100.0       None     1.0
# 4                        65400.0                  227000.0         BF     1.0
# ..                           ...                       ...        ...     ...
# 210                          NaN                       NaN       None     NaN
# 211                          NaN                       NaN       None     NaN
# 212                          NaN                       NaN       None     NaN
# 213                          NaN                       NaN       None     NaN
# 214                          NaN                       NaN       None     NaN
#
#       join_date  population  population_rank  internet_users  \
# 0          None    64979548             13.0      52308536.0
# 1          None   190015955             12.0      30557175.0
# 2          None    31624264             30.0      25343685.0
# 3          None    28250420             62.0       7548512.0
# 4    1993-03-29    19193382            101.0       3047909.0
# ..          ...         ...              ...             ...
# 210        None      436330            169.0        275717.0
# 211        None       38695            199.0         37553.0
# 212        None      428697            157.0        406705.0
# 213        None      108020            196.0         44558.0
# 214        None       34571            202.0         32494.0
#
#      internet_users_percentage  internet_user_rank
# 0                    80.500000                50.0
# 1                    27.510000               161.0
# 2                    80.139999                52.0
# 3                    26.719999               164.0
# 4                    15.880000               183.0
# ..                         ...                 ...
# 210                  63.189999                95.0
# 211                  97.050003                10.0
# 212                  94.870003                16.0
# 213                  41.250000               136.0
# 214                  94.440002                 NaN
#
# [215 rows x 14 columns]

# %%
spark.sql(
    """
    
    REFRESH TABLE tabd_db.P_EnterpriseSocialMediaUse
    
    """
)


spark.sql(
    """
    SELECT *
    FROM tabd_db.P_EnterpriseSocialMediaUse
    
    """
).toPandas()
# Out:
#        year                    region  percentage  \
# 0      2013  European Union from 2020           0
# 1      2013  European Union from 2020           0
# 2      2013  European Union from 2020           0
# 3      2013  European Union from 2020           0
# 4      2013  European Union from 2020           0
# ...     ...                       ...         ...
# 10287  2019    Bosnia and Herzegovina           0
# 10288  2019    Bosnia and Herzegovina           0
# 10289  2019    Bosnia and Herzegovina           0
# 10290  2019    Bosnia and Herzegovina           0
# 10291  2019    Bosnia and Herzegovina           0
#
#                                         advertising_type  \
# 0                       Pay to advertise on the internet
# 1      Enterprises using information about visitors b...
# 2      Have a website and pay to advertise on the int...
# 3      Have web sales to private consumers (B2C) and ...
# 4      Use social networks (Facebook, LinkedIn, Xing,...
# ...                                                  ...
# 10287  Use any social media, only for posting paid ad...
# 10288  Use any social media, only for posting paid ad...
# 10289  Use any social media, only for posting paid ad...
# 10290  Use any social media, only for posting paid ad...
# 10291  Use any social media, only for posting paid ad...
#
#                                                  purpose
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 10287  Use two or more social media for more than one...
# 10288  Use only one type of social medium for more th...
# 10289  Use two or more social media for only one purp...
# 10290  Use only one type of social medium for only on...
# 10291  Website has online ordering, reservation or bo...
#
# [10292 rows x 5 columns]

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS tabd_db.D_SocialMediaUsageForEnterprisesLevelDevelopment
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE tabd_db.D_SocialMediaUsageForEnterprisesLevelDevelopment (
    country_or_area VARCHAR(45),
    population_rank INT,
    internet_user_rank INT,
    purpose VARCHAR(45),
    ratio_percentage_enterprise DOUBLE,
    internet_users_percentage FLOAT,
    avg_internet_users_region DOUBLE,
    ratio_internet_users_region DOUBLE
      )
    STORED AS PARQUET
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/tabd.db/D_SocialMediaUsageForEnterprisesLevelDevelopment/'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    
    
    SELECT A.country_or_area,
 A.population_rank, 
 A.internet_user_rank,
A.purpose,
 ((E.total_percentage_region/F.total_percentage)*100) as ratio_percentage_enterprise,
 A.internet_users_percentage,
 B.avg_internet_users_region,
   ((C.total_internet_users_region/D.total_internet_users)*100) as ratio_internet_users_region
   
    
    FROM
   (SELECT DISTINCT tabd_db.P_EnterpriseSocialMediaUse.percentage,
 tabd_db.P_EnterpriseSocialMediaUse.purpose,
 tabd_db.P_CountryInternetUsers.country_or_area,
 tabd_db.P_CountryInternetUsers.internet_users_percentage,
 tabd_db.P_CountryInternetUsers.population_rank,
  tabd_db.P_CountryInternetUsers.internet_user_rank
 
 
  FROM (tabd_db.P_CountryInternetUsers 
    INNER JOIN tabd_db.P_EnterpriseSocialMediaUse 
    ON tabd_db.P_CountryInternetUsers.country_or_area = tabd_db.P_EnterpriseSocialMediaUse.region)) as A
    
    INNER JOIN 
    
    (SELECT DISTINCT country_or_area, AVG(internet_users_percentage) AS avg_internet_users_region
    FROM tabd_db.P_CountryInternetUsers   GROUP BY country_or_area
         ) as B 
    ON B.country_or_area = A.country_or_area

    INNER JOIN 
    
     (SELECT DISTINCT country_or_area, SUM(internet_users_percentage) AS total_internet_users_region
    FROM tabd_db.P_CountryInternetUsers
    GROUP BY country_or_area) as C
    ON C.country_or_area = A.country_or_area
    
    INNER JOIN 
(SELECT DISTINCT SUM(internet_users_percentage) AS total_internet_users
    FROM tabd_db.P_CountryInternetUsers) as D
    
    INNER JOIN 
    
     (SELECT DISTINCT region, SUM(percentage) AS total_percentage_region
    FROM tabd_db.P_EnterpriseSocialMediaUse
    GROUP BY region) as E
    ON E.region = A.country_or_area
    
    INNER JOIN 
(SELECT DISTINCT SUM(percentage) AS total_percentage
    FROM tabd_db.P_EnterpriseSocialMediaUse) as F
    
    """
).toPandas()
# Out:
#              country_or_area  population_rank  internet_user_rank  \
# 0                     Sweden               51                  12
# 1     Bosnia and Herzegovina              109                  80
# 2                    Finland               83                  29
# 3                     Latvia              125                  45
# 4                     Serbia               75                  76
# ...                      ...              ...                 ...
# 1290                 Iceland              164                   3
# 1291                 Hungary               63                  60
# 1292                 Estonia              133                  26
# 1293                  Latvia              125                  45
# 1294                   Malta              161                  53
#
#                                                 purpose  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1290  Use only one type of social medium for more th...
# 1291  Involve customers in development or innovation...
# 1292                                               None
# 1293                                               None
# 1294                                               None
#
#       ratio_percentage_enterprise  internet_users_percentage  \
# 0                        3.397165                  96.410004
# 1                        0.556084                  69.489998
# 2                        3.427497                  87.470001
# 3                        1.937193                  81.320000
# 4                        1.466038                  70.330002
# ...                           ...                        ...
# 1290                     2.068631                  98.260002
# 1291                     2.007967                  76.750000
# 1292                     2.337573                  88.099998
# 1293                     1.937193                  81.320000
# 1294                     4.284877                  80.070000
#
#       avg_internet_users_region  ratio_internet_users_region
# 0                     96.410004                     0.805718
# 1                     69.489998                     0.580742
# 2                     87.470001                     0.731004
# 3                     81.320000                     0.679608
# 4                     70.330002                     0.587762
# ...                         ...                          ...
# 1290                  98.260002                     0.821178
# 1291                  76.750000                     0.641415
# 1292                  88.099998                     0.736269
# 1293                  81.320000                     0.679608
# 1294                  80.070000                     0.669161
#
# [1295 rows x 8 columns]

# %%
countryusers = spark.sql(
      """
    
    
    SELECT A.country_or_area,
 A.population_rank, 
 A.internet_user_rank,
A.purpose,
 ((E.total_percentage_region/F.total_percentage)*100) as ratio_percentage_enterprise,
 A.internet_users_percentage,
 B.avg_internet_users_region,
   ((C.total_internet_users_region/D.total_internet_users)*100) as ratio_internet_users_region
   
    
    FROM
   (SELECT DISTINCT tabd_db.P_EnterpriseSocialMediaUse.percentage,
 tabd_db.P_EnterpriseSocialMediaUse.purpose,
 tabd_db.P_CountryInternetUsers.country_or_area,
 tabd_db.P_CountryInternetUsers.internet_users_percentage,
 tabd_db.P_CountryInternetUsers.population_rank,
  tabd_db.P_CountryInternetUsers.internet_user_rank
 
 
  FROM (tabd_db.P_CountryInternetUsers 
    INNER JOIN tabd_db.P_EnterpriseSocialMediaUse 
    ON tabd_db.P_CountryInternetUsers.country_or_area = tabd_db.P_EnterpriseSocialMediaUse.region)) as A
    
    INNER JOIN 
    
    (SELECT DISTINCT country_or_area, AVG(internet_users_percentage) AS avg_internet_users_region
    FROM tabd_db.P_CountryInternetUsers   GROUP BY country_or_area
         ) as B 
    ON B.country_or_area = A.country_or_area

    INNER JOIN 
    
     (SELECT DISTINCT country_or_area, SUM(internet_users_percentage) AS total_internet_users_region
    FROM tabd_db.P_CountryInternetUsers
    GROUP BY country_or_area) as C
    ON C.country_or_area = A.country_or_area
    
    INNER JOIN 
(SELECT DISTINCT SUM(internet_users_percentage) AS total_internet_users
    FROM tabd_db.P_CountryInternetUsers) as D
    
    INNER JOIN 
    
     (SELECT DISTINCT region, SUM(percentage) AS total_percentage_region
    FROM tabd_db.P_EnterpriseSocialMediaUse
    GROUP BY region) as E
    ON E.region = A.country_or_area
    
    INNER JOIN 
(SELECT DISTINCT SUM(percentage) AS total_percentage
    FROM tabd_db.P_EnterpriseSocialMediaUse) as F
    
    """
)

# %%
countryusers \
    .write \
    .format("parquet") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/warehouse/tabd.db/D_SocialMediaUsageForEnterprisesLevelDevelopment/")

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# spark = SparkSession.builder.master('local[2]').getOrCreate()

from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|adultinternetusag...|      false|
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalinternetusa...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|internetusagefreq...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausagef...|      false|
# | tabd_db|socialmediausebyp...|      false|
# +--------+--------------------+-----------+
# only showing top 20 rows

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020
    
    """
).show()
# Out:
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |              region|social_media_users|year|mobile_penetration_percentage|social_media_users_percentage|
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |        Eastern Asia|               0.0|2020|                            0|                         29.6|
# |      Southeast Asia|               0.0|2020|                            0|                         13.4|
# |       Southern Asia|               0.0|2020|                            0|                         13.1|
# |    Northern America|               0.0|2020|                            0|                          9.2|
# |       South America|               0.0|2020|                            0|                          7.6|
# |Central & Western...|               0.0|2020|                            0|                          5.5|
# |        Western Asia|               0.0|2020|                            0|                          4.4|
# |     Southern Europe|               0.0|2020|                            0|                          4.0|
# |      Eastern Europe|               0.0|2020|                            0|                          3.3|
# |     Northern Africa|               0.0|2020|                            0|                          3.0|
# |      Western Africa|               0.0|2020|                            0|                          1.5|
# |      Eastern Africa|               0.0|2020|                            0|                          1.2|
# |     Central America|               0.0|2020|                            0|                          0.8|
# |     Northern Europe|               0.0|2020|                            0|                          0.7|
# |     Southern Africa|               0.0|2020|                            0|                          0.7|
# | Australia & Oceania|               0.0|2020|                            0|                          0.7|
# |           Caribbean|               0.0|2020|                            0|                          0.6|
# |        Central Asia|               0.0|2020|                            0|                          0.4|
# |      Central Africa|               0.0|2020|                            0|                          0.3|
# +--------------------+------------------+----+-----------------------------+-----------------------------+

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.GlobalMobilePenetration
    
    """
).show()
# Out:
# +----------------+------------------+----+-----------------------------+-----------------------------+
# |          region|social_media_users|year|mobile_penetration_percentage|social_media_users_percentage|
# +----------------+------------------+----+-----------------------------+-----------------------------+
# |    Eastern Asia|               0.0|2020|                           70|                          0.0|
# |Northern America|               0.0|2020|                           61|                          0.0|
# |   South America|               0.0|2020|                           61|                          0.0|
# | Northern Europe|               0.0|2020|                           59|                          0.0|
# | Central America|               0.0|2020|                           59|                          0.0|
# |  Southeast Asia|               0.0|2020|                           56|                          0.0|
# |         Oceania|               0.0|2020|                           51|                          0.0|
# | Southern Europe|               0.0|2020|                           50|                          0.0|
# |    Western Asia|               0.0|2020|                           46|                          0.0|
# |  Western Europe|               0.0|2020|                           45|                          0.0|
# |       Caribbean|               0.0|2020|                           44|                          0.0|
# |  Global average|               0.0|2020|                           42|                          0.0|
# |  Eastern Europe|               0.0|2020|                           40|                          0.0|
# | Northern Africa|               0.0|2020|                           37|                          0.0|
# | Southern Africa|               0.0|2020|                           36|                          0.0|
# |   Southern Asia|               0.0|2020|                           22|                          0.0|
# |  Western Africa|               0.0|2020|                           12|                          0.0|
# |    Central Asia|               0.0|2020|                            8|                          0.0|
# |  Eastern Africa|               0.0|2020|                            7|                          0.0|
# |   Middle Africa|               0.0|2020|                            6|                          0.0|
# +----------------+------------------+----+-----------------------------+-----------------------------+

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.NumberOfWorldwideSocialMediaUse
    
    """
).show()
# Out:
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |              region|social_media_users|year|mobile_penetration_percentage|social_media_users_percentage|
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |        Eastern Asia|           1065.88|2020|                            0|                          0.0|
# |      Southeast Asia|            482.73|2020|                            0|                          0.0|
# |       Southern Asia|            470.01|2020|                            0|                          0.0|
# |    Northern America|            329.25|2020|                            0|                          0.0|
# |       South America|            274.22|2020|                            0|                          0.0|
# |Central & Western...|            198.07|2020|                            0|                          0.0|
# |        Western Asia|            158.96|2020|                            0|                          0.0|
# |     Southern Europe|            143.27|2020|                            0|                          0.0|
# |      Eastern Europe|            117.47|2020|                            0|                          0.0|
# |     Northern Africa|            106.48|2020|                            0|                          0.0|
# |      Western Africa|             55.06|2020|                            0|                          0.0|
# |      Eastern Africa|             42.91|2020|                            0|                          0.0|
# |     Central America|             29.66|2020|                            0|                          0.0|
# |     Southern Africa|             26.37|2020|                            0|                          0.0|
# |     Northern Europe|             24.05|2020|                            0|                          0.0|
# | Australia & Oceania|             23.57|2020|                            0|                          0.0|
# |           Caribbean|              21.3|2020|                            0|                          0.0|
# |        Central Asia|             13.93|2020|                            0|                          0.0|
# |      Central Africa|             12.38|2020|                            0|                          0.0|
# +--------------------+------------------+----+-----------------------------+-----------------------------+

# %%
GlobalSocialMediaUsage = spark.sql(
    """
    
    SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage
    
    FROM (
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020 
      UNION ALL 
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.GlobalMobilePenetration
      UNION ALL
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.NumberOfWorldwideSocialMediaUse
     ) 
     
     GROUP BY region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage
        
    """
)

# %%
spark.sql(
    """
    
    SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage
    
    FROM (
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020 
      UNION ALL 
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.GlobalMobilePenetration
      UNION ALL
      SELECT region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage FROM tabd_db.NumberOfWorldwideSocialMediaUse
     ) 
     
     GROUP BY region, social_media_users, year, mobile_penetration_percentage, social_media_users_percentage
        
    """
).toPandas()
# Out:
#                       region  social_media_users  year  \
# 0             Global average                0.00  2020
# 1             Southeast Asia              482.73  2020
# 2              Southern Asia              470.01  2020
# 3            Northern Africa              106.48  2020
# 4            Southern Europe              143.27  2020
# 5               Western Asia                0.00  2020
# 6              Southern Asia                0.00  2020
# 7              South America                0.00  2020
# 8               Central Asia               13.93  2020
# 9            Central America               29.66  2020
# 10                 Caribbean               21.30  2020
# 11           Northern Africa                0.00  2020
# 12                   Oceania                0.00  2020
# 13           Southern Africa                0.00  2020
# 14            Central Africa                0.00  2020
# 15            Western Africa                0.00  2020
# 16              Eastern Asia                0.00  2020
# 17  Central & Western Europe              198.07  2020
# 18           Southern Europe                0.00  2020
# 19          Northern America                0.00  2020
# 20            Eastern Europe              117.47  2020
# 21            Eastern Africa                0.00  2020
# 22           Northern Europe               24.05  2020
# 23          Northern America              329.25  2020
# 24              Western Asia                0.00  2020
# 25             Middle Africa                0.00  2020
# 26            Southeast Asia                0.00  2020
# 27            Western Europe                0.00  2020
# 28              Eastern Asia                0.00  2020
# 29            Central Africa               12.38  2020
# 30            Eastern Africa                0.00  2020
# 31           Central America                0.00  2020
# 32             South America              274.22  2020
# 33           Southern Africa                0.00  2020
# 34             Southern Asia                0.00  2020
# 35              Central Asia                0.00  2020
# 36              Eastern Asia             1065.88  2020
# 37                 Caribbean                0.00  2020
# 38              Central Asia                0.00  2020
# 39           Southern Africa               26.37  2020
# 40       Australia & Oceania               23.57  2020
# 41            Southeast Asia                0.00  2020
# 42            Eastern Africa               42.91  2020
# 43              Western Asia              158.96  2020
# 44            Eastern Europe                0.00  2020
# 45  Central & Western Europe                0.00  2020
# 46           Southern Europe                0.00  2020
# 47           Northern Europe                0.00  2020
# 48            Eastern Europe                0.00  2020
# 49          Northern America                0.00  2020
# 50                 Caribbean                0.00  2020
# 51            Western Africa               55.06  2020
# 52       Australia & Oceania                0.00  2020
# 53           Northern Europe                0.00  2020
# 54           Northern Africa                0.00  2020
# 55            Western Africa                0.00  2020
# 56           Central America                0.00  2020
# 57             South America                0.00  2020
#
#     mobile_penetration_percentage  social_media_users_percentage
# 0                              42                            0.0
# 1                               0                            0.0
# 2                               0                            0.0
# 3                               0                            0.0
# 4                               0                            0.0
# 5                               0                            4.4
# 6                               0                           13.1
# 7                              61                            0.0
# 8                               0                            0.0
# 9                               0                            0.0
# 10                              0                            0.0
# 11                             37                            0.0
# 12                             51                            0.0
# 13                              0                            0.7
# 14                              0                            0.3
# 15                             12                            0.0
# 16                              0                           29.6
# 17                              0                            0.0
# 18                              0                            4.0
# 19                              0                            9.2
# 20                              0                            0.0
# 21                              7                            0.0
# 22                              0                            0.0
# 23                              0                            0.0
# 24                             46                            0.0
# 25                              6                            0.0
# 26                              0                           13.4
# 27                             45                            0.0
# 28                             70                            0.0
# 29                              0                            0.0
# 30                              0                            1.2
# 31                              0                            0.8
# 32                              0                            0.0
# 33                             36                            0.0
# 34                             22                            0.0
# 35                              0                            0.4
# 36                              0                            0.0
# 37                              0                            0.6
# 38                              8                            0.0
# 39                              0                            0.0
# 40                              0                            0.0
# 41                             56                            0.0
# 42                              0                            0.0
# 43                              0                            0.0
# 44                             40                            0.0
# 45                              0                            5.5
# 46                             50                            0.0
# 47                             59                            0.0
# 48                              0                            3.3
# 49                             61                            0.0
# 50                             44                            0.0
# 51                              0                            0.0
# 52                              0                            0.7
# 53                              0                            0.7
# 54                              0                            3.0
# 55                              0                            1.5
# 56                             59                            0.0
# 57                              0                            7.6

# %%
GlobalSocialMediaUsage \
    .write \
    .format("parquet") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/warehouse/tabd.db/GlobalSocialMediaUsage/")

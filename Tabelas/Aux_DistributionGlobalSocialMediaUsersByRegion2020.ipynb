# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausagef...|      false|
# | tabd_db|socialmediausebyp...|      false|
# | tabd_db|socialmediausebyt...|      false|
# | tabd_db|socialmediausersa...|      false|
# | tabd_db|  socialnetworkusers|      false|
# +--------+--------------------+-----------+

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS tabd_db.DistributionGlobalSocialMediaUsersByRegion2020 
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE tabd_db.DistributionGlobalSocialMediaUsersByRegion2020  (
        region VARCHAR(45),
        social_media_users DOUBLE,
        year INT,
        mobile_penetration_percentage INT,
        social_media_users_percentage FLOAT
    )
    STORED AS PARQUET
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/tabd.db/DistributionGlobalSocialMediaUsersByRegion2020/'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausagef...|      false|
# | tabd_db|socialmediausebyp...|      false|
# | tabd_db|socialmediausebyt...|      false|
# | tabd_db|socialmediausersa...|      false|
# | tabd_db|  socialnetworkusers|      false|
# +--------+--------------------+-----------+

# %%
# Let's look into HDFS
spark.sql(
    """
    SELECT *
    FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020
    """
).show()
# Out:
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |              region|social_media_users|year|mobile_penetration_percentage|social_media_users_percentage|
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |        Eastern Asia|               0.0|2020|                            0|                         29.6|
# |      Southeast Asia|               0.0|2020|                            0|                         13.4|
# |       Southern Asia|               0.0|2020|                            0|                         13.1|
# |    Northern America|               0.0|2020|                            0|                          9.2|
# |       South America|               0.0|2020|                            0|                          7.6|
# |Central & Western...|               0.0|2020|                            0|                          5.5|
# |        Western Asia|               0.0|2020|                            0|                          4.4|
# |     Southern Europe|               0.0|2020|                            0|                          4.0|
# |      Eastern Europe|               0.0|2020|                            0|                          3.3|
# |     Northern Africa|               0.0|2020|                            0|                          3.0|
# |      Western Africa|               0.0|2020|                            0|                          1.5|
# |      Eastern Africa|               0.0|2020|                            0|                          1.2|
# |     Central America|               0.0|2020|                            0|                          0.8|
# |     Northern Europe|               0.0|2020|                            0|                          0.7|
# |     Southern Africa|               0.0|2020|                            0|                          0.7|
# | Australia & Oceania|               0.0|2020|                            0|                          0.7|
# |           Caribbean|               0.0|2020|                            0|                          0.6|
# |        Central Asia|               0.0|2020|                            0|                          0.4|
# |      Central Africa|               0.0|2020|                            0|                          0.3|
# +--------------------+------------------+----+-----------------------------+-----------------------------+

# %%
spark.sql(
    """
    DESCRIBE FORMATTED tabd_db.DistributionGlobalSocialMediaUsersByRegion2020
    """
).toPandas()
# Out:
#                          col_name  \
# 0                          region
# 1              social_media_users
# 2                            year
# 3   mobile_penetration_percentage
# 4   social_media_users_percentage
# 5
# 6    # Detailed Table Information
# 7                        Database
# 8                           Table
# 9                           Owner
# 10                   Created Time
# 11                    Last Access
# 12                     Created By
# 13                           Type
# 14                       Provider
# 15               Table Properties
# 16                     Statistics
# 17                       Location
# 18                  Serde Library
# 19                    InputFormat
# 20                   OutputFormat
# 21             Storage Properties
# 22             Partition Provider
#
#                                             data_type comment
# 0                                         varchar(45)    None
# 1                                              double    None
# 2                                                 int    None
# 3                                                 int    None
# 4                                               float    None
# 5
# 6
# 7                                             tabd_db
# 8      distributionglobalsocialmediausersbyregion2020
# 9                                              jovyan
# 10                       Wed Jun 09 12:47:07 UTC 2021
# 11                                            UNKNOWN
# 12                                        Spark 3.1.1
# 13                                           EXTERNAL
# 14                                               hive
# 15                 [transient_lastDdlTime=1623242827]
# 16                                         1832 bytes
# 17  hdfs://hdfs-nn:9000/warehouse/tabd.db/Distribu...
# 18  org.apache.hadoop.hive.ql.io.parquet.serde.Par...
# 19  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 20  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 21                           [serialization.format=1]
# 22                                            Catalog

# %%
# Let's put the files into HDFS

spark.sql(
    """
    SELECT *
    FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020
    """
).toPandas()
# Out:
#                       region  social_media_users  year  \
# 0               Eastern Asia                 0.0  2020
# 1             Southeast Asia                 0.0  2020
# 2              Southern Asia                 0.0  2020
# 3           Northern America                 0.0  2020
# 4              South America                 0.0  2020
# 5   Central & Western Europe                 0.0  2020
# 6               Western Asia                 0.0  2020
# 7            Southern Europe                 0.0  2020
# 8             Eastern Europe                 0.0  2020
# 9            Northern Africa                 0.0  2020
# 10            Western Africa                 0.0  2020
# 11            Eastern Africa                 0.0  2020
# 12           Central America                 0.0  2020
# 13           Northern Europe                 0.0  2020
# 14           Southern Africa                 0.0  2020
# 15       Australia & Oceania                 0.0  2020
# 16                 Caribbean                 0.0  2020
# 17              Central Asia                 0.0  2020
# 18            Central Africa                 0.0  2020
#
#     mobile_penetration_percentage  social_media_users_percentage
# 0                               0                           29.6
# 1                               0                           13.4
# 2                               0                           13.1
# 3                               0                            9.2
# 4                               0                            7.6
# 5                               0                            5.5
# 6                               0                            4.4
# 7                               0                            4.0
# 8                               0                            3.3
# 9                               0                            3.0
# 10                              0                            1.5
# 11                              0                            1.2
# 12                              0                            0.8
# 13                              0                            0.7
# 14                              0                            0.7
# 15                              0                            0.7
# 16                              0                            0.6
# 17                              0                            0.4
# 18                              0                            0.3

# %%
# recover partitions is needed so that the Hive Metastore (Catalog)
# is updated. Otherwise Hive and the querying engines do not know
# that there are new parittions in the partitioned table.

spark.sql(
    """
    SELECT *
    FROM tabd_db.DistributionGlobalSocialMediaUsersByRegion2020
    """
).show()
# Out:
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |              region|social_media_users|year|mobile_penetration_percentage|social_media_users_percentage|
# +--------------------+------------------+----+-----------------------------+-----------------------------+
# |        Eastern Asia|               0.0|2020|                            0|                         29.6|
# |      Southeast Asia|               0.0|2020|                            0|                         13.4|
# |       Southern Asia|               0.0|2020|                            0|                         13.1|
# |    Northern America|               0.0|2020|                            0|                          9.2|
# |       South America|               0.0|2020|                            0|                          7.6|
# |Central & Western...|               0.0|2020|                            0|                          5.5|
# |        Western Asia|               0.0|2020|                            0|                          4.4|
# |     Southern Europe|               0.0|2020|                            0|                          4.0|
# |      Eastern Europe|               0.0|2020|                            0|                          3.3|
# |     Northern Africa|               0.0|2020|                            0|                          3.0|
# |      Western Africa|               0.0|2020|                            0|                          1.5|
# |      Eastern Africa|               0.0|2020|                            0|                          1.2|
# |     Central America|               0.0|2020|                            0|                          0.8|
# |     Northern Europe|               0.0|2020|                            0|                          0.7|
# |     Southern Africa|               0.0|2020|                            0|                          0.7|
# | Australia & Oceania|               0.0|2020|                            0|                          0.7|
# |           Caribbean|               0.0|2020|                            0|                          0.6|
# |        Central Asia|               0.0|2020|                            0|                          0.4|
# |      Central Africa|               0.0|2020|                            0|                          0.3|
# +--------------------+------------------+----+-----------------------------+-----------------------------+

# %%
spark.stop()

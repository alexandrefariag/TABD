# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|           countries|      false|
# | tabd_db|countryinternetusers|      false|
# | tabd_db|dailyinternetusag...|      false|
# | tabd_db|    internetjoindate|      false|
# | tabd_db|listleastdevelope...|      false|
# | tabd_db|listofcountriesby...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausebyp...|      false|
# | tabd_db|socialmediausebyt...|      false|
# +--------+--------------------+-----------+

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS tabd_db.P_CountryInternetUsers
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE tabd_db.P_CountryInternetUsers (
    country_or_area VARCHAR(45),
        area_km VARCHAR(45),
        current_account_balance INT,
        internet_hosts INT,
        telephone_main_lines_in_use INT,
        telephone_mobile_celular INT,
        country_id VARCHAR(45),
        status INT,
        join_date DATE,
        population INT,
        population_rank INT,
        internet_users INT,
        internet_users_percentage FLOAT,
        internet_user_rank INT
    )
    STORED AS PARQUET
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/tabd.db/P_CountryInternetUsers/'
    """
)

# tblproperties('skip.header.line.count'='1')
# can be used for csvs with header
# but spark sql cannot understand that at the moment, while reading the data using sql queries
# so just when creating hive tables backed up by csvs, avoid headers
# in the project we wont use hive text tables, so all good.
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|           countries|      false|
# | tabd_db|countryinternetusers|      false|
# | tabd_db|dailyinternetusag...|      false|
# | tabd_db|    internetjoindate|      false|
# | tabd_db|listleastdevelope...|      false|
# | tabd_db|listofcountriesby...|      false|
# | tabd_db|p_countryinternet...|      false|
# | tabd_db|p_enterprisesocia...|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausebyp...|      false|
# | tabd_db|socialmediausebyt...|      false|
# +--------+--------------------+-----------+

# %%
# Let's look into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.P_CountryInternetUsers
    """
).show()
# Out:
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# |country_or_area|area_km|current_account_balance|internet_hosts|telephone_main_lines_in_use|telephone_mobile_celular|country_id|status|join_date|population|population_rank|internet_users|internet_users_percentage|internet_user_rank|
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+

# %%
spark.sql(
    """
    DESCRIBE FORMATTED tabd_db.P_CountryInternetUsers
    """
).toPandas()
# Out:
#                         col_name  \
# 0                country_or_area
# 1                        area_km
# 2        current_account_balance
# 3                 internet_hosts
# 4    telephone_main_lines_in_use
# 5       telephone_mobile_celular
# 6                     country_id
# 7                         status
# 8                      join_date
# 9                     population
# 10               population_rank
# 11                internet_users
# 12     internet_users_percentage
# 13            internet_user_rank
# 14
# 15  # Detailed Table Information
# 16                      Database
# 17                         Table
# 18                         Owner
# 19                  Created Time
# 20                   Last Access
# 21                    Created By
# 22                          Type
# 23                      Provider
# 24              Table Properties
# 25                      Location
# 26                 Serde Library
# 27                   InputFormat
# 28                  OutputFormat
# 29            Storage Properties
# 30            Partition Provider
#
#                                             data_type comment
# 0                                         varchar(45)    None
# 1                                         varchar(45)    None
# 2                                                 int    None
# 3                                                 int    None
# 4                                                 int    None
# 5                                                 int    None
# 6                                         varchar(45)    None
# 7                                                 int    None
# 8                                                date    None
# 9                                                 int    None
# 10                                                int    None
# 11                                                int    None
# 12                                              float    None
# 13                                                int    None
# 14
# 15
# 16                                            tabd_db
# 17                             p_countryinternetusers
# 18                                             jovyan
# 19                       Wed Jun 09 12:59:23 UTC 2021
# 20                                            UNKNOWN
# 21                                        Spark 3.1.1
# 22                                           EXTERNAL
# 23                                               hive
# 24                 [transient_lastDdlTime=1623243563]
# 25  hdfs://hdfs-nn:9000/warehouse/tabd.db/P_Countr...
# 26  org.apache.hadoop.hive.ql.io.parquet.serde.Par...
# 27  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 28  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 29                           [serialization.format=1]
# 30                                            Catalog

# %%
# Let's put the files into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.P_CountryInternetUsers
    """
).toPandas()
# Out:
# Empty DataFrame
# Columns: [country_or_area, area_km, current_account_balance, internet_hosts, telephone_main_lines_in_use, telephone_mobile_celular, country_id, status, join_date, population, population_rank, internet_users, internet_users_percentage, internet_user_rank]
# Index: []

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.P_CountryInternetUsers
    """
).show()
# Out:
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# |country_or_area|area_km|current_account_balance|internet_hosts|telephone_main_lines_in_use|telephone_mobile_celular|country_id|status|join_date|population|population_rank|internet_users|internet_users_percentage|internet_user_rank|
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+

# %%
spark.stop()

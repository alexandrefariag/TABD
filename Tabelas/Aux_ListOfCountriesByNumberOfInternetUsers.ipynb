# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|           countries|      false|
# | tabd_db|countryinternetusers|      false|
# | tabd_db|dailyinternetusag...|      false|
# | tabd_db|    internetjoindate|      false|
# | tabd_db|listleastdevelope...|      false|
# | tabd_db|listofcountriesby...|      false|
# +--------+--------------------+-----------+

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS tabd_db.ListOfCountriesByNumberOfInternetUsers
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE tabd_db.ListOfCountriesByNumberOfInternetUsers (
    country_or_area VARCHAR(45),
        area_km VARCHAR(45),
        current_account_balance INT,
        internet_hosts INT,
        telephone_main_lines_in_use INT,
        telephone_mobile_celular INT,
        country_id VARCHAR(45),
        status INT,
        join_date DATE,
        population INT,
        population_rank INT,
        internet_users INT,
        internet_users_percentage FLOAT,
        internet_user_rank INT
    )
    STORED AS PARQUET
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/tabd.db/ListOfCountriesByNumberOfInternetUsers/'
    """
)

# tblproperties('skip.header.line.count'='1')
# can be used for csvs with header
# but spark sql cannot understand that at the moment, while reading the data using sql queries
# so just when creating hive tables backed up by csvs, avoid headers
# in the project we wont use hive text tables, so all good.
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|           countries|      false|
# | tabd_db|countryinternetusers|      false|
# | tabd_db|dailyinternetusag...|      false|
# | tabd_db|    internetjoindate|      false|
# | tabd_db|listleastdevelope...|      false|
# | tabd_db|listofcountriesby...|      false|
# +--------+--------------------+-----------+

# %%
# Let's look into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.ListOfCountriesByNumberOfInternetUsers
    """
).show()
# Out:
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# |country_or_area|area_km|current_account_balance|internet_hosts|telephone_main_lines_in_use|telephone_mobile_celular|country_id|status|join_date|population|population_rank|internet_users|internet_users_percentage|internet_user_rank|
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+

# %%
spark.sql(
    """
    DESCRIBE FORMATTED tabd_db.ListOfCountriesByNumberOfInternetUsers
    """
).toPandas()
# Out:
#                         col_name  \
# 0                country_or_area
# 1                        area_km
# 2        current_account_balance
# 3                 internet_hosts
# 4    telephone_main_lines_in_use
# 5       telephone_mobile_celular
# 6                     country_id
# 7                         status
# 8                      join_date
# 9                     population
# 10               population_rank
# 11                internet_users
# 12     internet_users_percentage
# 13            internet_user_rank
# 14
# 15  # Detailed Table Information
# 16                      Database
# 17                         Table
# 18                         Owner
# 19                  Created Time
# 20                   Last Access
# 21                    Created By
# 22                          Type
# 23                      Provider
# 24              Table Properties
# 25                      Location
# 26                 Serde Library
# 27                   InputFormat
# 28                  OutputFormat
# 29            Storage Properties
# 30            Partition Provider
#
#                                             data_type comment
# 0                                         varchar(45)    None
# 1                                         varchar(45)    None
# 2                                                 int    None
# 3                                                 int    None
# 4                                                 int    None
# 5                                                 int    None
# 6                                         varchar(45)    None
# 7                                                 int    None
# 8                                                date    None
# 9                                                 int    None
# 10                                                int    None
# 11                                                int    None
# 12                                              float    None
# 13                                                int    None
# 14
# 15
# 16                                            tabd_db
# 17             listofcountriesbynumberofinternetusers
# 18                                             jovyan
# 19                       Tue Jun 08 21:26:07 UTC 2021
# 20                                            UNKNOWN
# 21                                        Spark 3.1.1
# 22                                           EXTERNAL
# 23                                               hive
# 24                 [transient_lastDdlTime=1623187567]
# 25  hdfs://hdfs-nn:9000/warehouse/tabd.db/ListOfCo...
# 26  org.apache.hadoop.hive.ql.io.parquet.serde.Par...
# 27  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 28  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 29                           [serialization.format=1]
# 30                                            Catalog

# %%
# Let's put the files into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.ListOfCountriesByNumberOfInternetUsers
    """
).toPandas()
# Out:
#        country_or_area area_km  current_account_balance  internet_hosts  \
# 0                China       0                        0               0
# 1                India       0                        0               0
# 2        United States       0                        0               0
# 3               Brazil       0                        0               0
# 4                Japan       0                        0               0
# ..                 ...     ...                      ...             ...
# 210   Falkland Islands       0                        0               0
# 211         Montserrat       0                        0               0
# 212  Wallis and Futuna       0                        0               0
# 213               Niue       0                        0               0
# 214          Ascension       0                        0               0
#
#      telephone_main_lines_in_use  telephone_mobile_celular country_id  status  \
# 0                              0                       NaN                  0
# 1                              0                       NaN                  0
# 2                              0                       NaN                  0
# 3                              0                       NaN                  0
# 4                              0                       NaN                  0
# ..                           ...                       ...        ...     ...
# 210                            0                       NaN                  0
# 211                            0                       NaN                  0
# 212                            0                       NaN                  0
# 213                            0                       NaN                  0
# 214                            0                       NaN                  0
#
#     join_date  population  population_rank  internet_users  \
# 0        None  1409517397              1.0     765367947.0
# 1        None  1339180127              2.0     461347554.0
# 2        None   324459463              3.0     244090854.0
# 3        None   209288278              4.0     141206801.0
# 4        None   127484450              5.0     115845120.0
# ..        ...         ...              ...             ...
# 210      None        2910            211.0          2881.0
# 211      None        5177            212.0          2833.0
# 212      None       11773            213.0          1383.0
# 213      None        1618            214.0          1034.0
# 214      None         806            215.0           361.0
#
#      internet_users_percentage  internet_user_rank
# 0                    54.299999               116.0
# 1                    34.450001               145.0
# 2                    75.230003                68.0
# 3                    67.470001                83.0
# 4                    90.870003                23.0
# ..                         ...                 ...
# 210                  99.019997                 NaN
# 211                  54.549999               115.0
# 212                   8.950000                 NaN
# 213                  86.900002                30.0
# 214                  41.029999                 NaN
#
# [215 rows x 14 columns]

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.ListOfCountriesByNumberOfInternetUsers
    """
).show()
# Out:
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# |country_or_area|area_km|current_account_balance|internet_hosts|telephone_main_lines_in_use|telephone_mobile_celular|country_id|status|join_date|population|population_rank|internet_users|internet_users_percentage|internet_user_rank|
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+
# +---------------+-------+-----------------------+--------------+---------------------------+------------------------+----------+------+---------+----------+---------------+--------------+-------------------------+------------------+

# %%
spark.stop()

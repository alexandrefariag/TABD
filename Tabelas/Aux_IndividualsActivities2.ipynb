# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.functions import *

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/warehouse'

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .enableHiveSupport() \
    .getOrCreate()

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|adultinternetusag...|      false|
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalinternetusa...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|internetusagefreq...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausagef...|      false|
# +--------+--------------------+-----------+
# only showing top 20 rows

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS tabd_db.IndividualsActivities2
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE tabd_db.IndividualsActivities2 (
        year INT,
        region VARCHAR(45),
        internet_activity VARCHAR(45),
        activity_percentage INT,
        individuals VARCHAR(45)

    )
    STORED AS PARQUET
    LOCATION 'hdfs://hdfs-nn:9000/warehouse/tabd.db/IndividualsActivities2/'
    """
)

        

# tblproperties('skip.header.line.count'='1')
# can be used for csvs with header
# but spark sql cannot understand that at the moment, while reading the data using sql queries
# so just when creating hive tables backed up by csvs, avoid headers
# in the project we wont use hive text tables, so all good.
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    SHOW TABLES FROM tabd_db
    """
).show()
# Out:
# +--------+--------------------+-----------+
# |database|           tableName|isTemporary|
# +--------+--------------------+-----------+
# | tabd_db|adultinternetusag...|      false|
# | tabd_db|distributiongloba...|      false|
# | tabd_db|globalinternetusa...|      false|
# | tabd_db|globalmobilepenet...|      false|
# | tabd_db|globalsocialnetworks|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db|individualsactivi...|      false|
# | tabd_db| internetactivities1|      false|
# | tabd_db| internetactivities2|      false|
# | tabd_db|       internetusage|      false|
# | tabd_db|internetusagefreq...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|numberofworldwide...|      false|
# | tabd_db|p_dailyinternetus...|      false|
# | tabd_db|p_globalsocialmed...|      false|
# | tabd_db|p_globalsocialnet...|      false|
# | tabd_db|p_individualsacti...|      false|
# | tabd_db|     p_internetusage|      false|
# | tabd_db|parentawarenessof...|      false|
# | tabd_db|socialmediausagef...|      false|
# +--------+--------------------+-----------+
# only showing top 20 rows

# %%
# Let's look into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.IndividualsActivities2
    """
).show()
# Out:
# +----+--------------------+--------------------+-------------------+-----------+
# |year|              region|   internet_activity|activity_percentage|individuals|
# +----+--------------------+--------------------+-------------------+-----------+
# |2011|European Union fr...|Looking for infor...|                 28|       null|
# |2012|European Union fr...|Looking for infor...|                  0|       null|
# |2013|European Union fr...|Looking for infor...|                 30|       null|
# |2014|European Union fr...|Looking for infor...|                  0|       null|
# |2015|European Union fr...|Looking for infor...|                 31|       null|
# |2016|European Union fr...|Looking for infor...|                  0|       null|
# |2017|European Union fr...|Looking for infor...|                  0|       null|
# |2018|European Union fr...|Looking for infor...|                  0|       null|
# |2019|European Union fr...|Looking for infor...|                  0|       null|
# |2020|European Union fr...|Looking for infor...|                  0|       null|
# |2011|European Union fr...|Sending/receiving...|                  0|       null|
# |2012|European Union fr...|Sending/receiving...|                 64|       null|
# |2013|European Union fr...|Sending/receiving...|                 65|       null|
# |2014|European Union fr...|Sending/receiving...|                 67|       null|
# |2015|European Union fr...|Sending/receiving...|                 67|       null|
# |2016|European Union fr...|Sending/receiving...|                 69|       null|
# |2017|European Union fr...|Sending/receiving...|                 70|       null|
# |2018|European Union fr...|Sending/receiving...|                 71|       null|
# |2019|European Union fr...|Sending/receiving...|                 73|       null|
# |2020|European Union fr...|Sending/receiving...|                 75|       null|
# +----+--------------------+--------------------+-------------------+-----------+
# only showing top 20 rows

# %%
spark.sql(
    """
    DESCRIBE FORMATTED tabd_db.IndividualsActivities2
    """
).toPandas()
# Out:
#                         col_name  \
# 0                           year
# 1                         region
# 2              internet_activity
# 3            activity_percentage
# 4                    individuals
# 5
# 6   # Detailed Table Information
# 7                       Database
# 8                          Table
# 9                          Owner
# 10                  Created Time
# 11                   Last Access
# 12                    Created By
# 13                          Type
# 14                      Provider
# 15              Table Properties
# 16                    Statistics
# 17                      Location
# 18                 Serde Library
# 19                   InputFormat
# 20                  OutputFormat
# 21            Storage Properties
# 22            Partition Provider
#
#                                             data_type comment
# 0                                                 int    None
# 1                                         varchar(45)    None
# 2                                         varchar(45)    None
# 3                                                 int    None
# 4                                         varchar(45)    None
# 5
# 6
# 7                                             tabd_db
# 8                              individualsactivities2
# 9                                              jovyan
# 10                       Tue Jun 08 21:51:58 UTC 2021
# 11                                            UNKNOWN
# 12                                        Spark 3.1.1
# 13                                           EXTERNAL
# 14                                               hive
# 15                 [transient_lastDdlTime=1623189118]
# 16                                         6743 bytes
# 17  hdfs://hdfs-nn:9000/warehouse/tabd.db/Individu...
# 18  org.apache.hadoop.hive.ql.io.parquet.serde.Par...
# 19  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 20  org.apache.hadoop.hive.ql.io.parquet.MapredPar...
# 21                           [serialization.format=1]
# 22                                            Catalog

# %%
# Let's put the files into HDFS

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.IndividualsActivities2
    """
).toPandas()
# Out:
#       year                    region  \
# 0     2011  European Union from 2020
# 1     2012  European Union from 2020
# 2     2013  European Union from 2020
# 3     2014  European Union from 2020
# 4     2015  European Union from 2020
# ...    ...                       ...
# 5275  2016               South Korea
# 5276  2017               South Korea
# 5277  2018               South Korea
# 5278  2019               South Korea
# 5279  2020               South Korea
#
#                                       internet_activity  activity_percentage  \
# 0     Looking for information about education, train...                   28
# 1     Looking for information about education, train...                    0
# 2     Looking for information about education, train...                   30
# 3     Looking for information about education, train...                    0
# 4     Looking for information about education, train...                   31
# ...                                                 ...                  ...
# 5275  Playing/downloading games, listening to music ...                    0
# 5276  Playing/downloading games, listening to music ...                    0
# 5277  Playing/downloading games, listening to music ...                    0
# 5278  Playing/downloading games, listening to music ...                    0
# 5279  Playing/downloading games, listening to music ...                    0
#
#      individuals
# 0           null
# 1           null
# 2           null
# 3           null
# 4           null
# ...          ...
# 5275        null
# 5276        null
# 5277        null
# 5278        null
# 5279        null
#
# [5280 rows x 5 columns]

# %%
spark.sql(
    """
    SELECT *
    FROM tabd_db.IndividualsActivities2
    """
).show()
# Out:
# +----+--------------------+--------------------+-------------------+-----------+
# |year|              region|   internet_activity|activity_percentage|individuals|
# +----+--------------------+--------------------+-------------------+-----------+
# |2011|European Union fr...|Looking for infor...|                 28|       null|
# |2012|European Union fr...|Looking for infor...|                  0|       null|
# |2013|European Union fr...|Looking for infor...|                 30|       null|
# |2014|European Union fr...|Looking for infor...|                  0|       null|
# |2015|European Union fr...|Looking for infor...|                 31|       null|
# |2016|European Union fr...|Looking for infor...|                  0|       null|
# |2017|European Union fr...|Looking for infor...|                  0|       null|
# |2018|European Union fr...|Looking for infor...|                  0|       null|
# |2019|European Union fr...|Looking for infor...|                  0|       null|
# |2020|European Union fr...|Looking for infor...|                  0|       null|
# |2011|European Union fr...|Sending/receiving...|                  0|       null|
# |2012|European Union fr...|Sending/receiving...|                 64|       null|
# |2013|European Union fr...|Sending/receiving...|                 65|       null|
# |2014|European Union fr...|Sending/receiving...|                 67|       null|
# |2015|European Union fr...|Sending/receiving...|                 67|       null|
# |2016|European Union fr...|Sending/receiving...|                 69|       null|
# |2017|European Union fr...|Sending/receiving...|                 70|       null|
# |2018|European Union fr...|Sending/receiving...|                 71|       null|
# |2019|European Union fr...|Sending/receiving...|                 73|       null|
# |2020|European Union fr...|Sending/receiving...|                 75|       null|
# +----+--------------------+--------------------+-------------------+-----------+
# only showing top 20 rows

# %%
spark.stop()
